# %% [markdown]
# # Code sample using the Network Component library

# %%
# %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
print(1)
from matplotlib.pyplot import *
# Out:
# 1

# %%
x = np.linspace(0, 5, 10)
y = x ** 2

# %%
figure()
plot(x, y, 'r')
xlabel('x')
ylabel('y')
title('title')
show()
# Out:
# <img src="data:image/png;base64,...">
